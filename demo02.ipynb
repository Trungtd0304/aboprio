# %%
import findspark

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName("Operations").getOrCreate()

# %%
df = spark.read.csv('appl_stock.csv',inferSchema=True,header=True)

# %%
df.show()
# Out:
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# |               Date|              Open|              High|               Low|             Close|   Volume|         Adj Close|
# +-------------------+------------------+------------------+------------------+------------------+---------+------------------+
# |2010-01-04 00:00:00|        213.429998|        214.499996|212.38000099999996|        214.009998|123432400|         27.727039|
# |2010-01-05 00:00:00|        214.599998|        215.589994|        213.249994|        214.379993|150476200|27.774976000000002|
# |2010-01-06 00:00:00|        214.379993|            215.23|        210.750004|        210.969995|138040000|27.333178000000004|
# |2010-01-07 00:00:00|            211.75|        212.000006|        209.050005|            210.58|119282800|          27.28265|
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- Date: timestamp (nullable = true)
#  |-- Open: double (nullable = true)
#  |-- High: double (nullable = true)
#  |-- Low: double (nullable = true)
#  |-- Close: double (nullable = true)
#  |-- Volume: integer (nullable = true)
#  |-- Adj Close: double (nullable = true)

# %%
df.head()
# Out:
# Row(Date=datetime.datetime(2010, 1, 4, 0, 0), Open=213.429998, High=214.499996, Low=212.38000099999996, Close=214.009998, Volume=123432400, Adj Close=27.727039)

# %%
df.filter('Close < 500').select(['Open','Close']).show()
# Out:
# +------------------+------------------+
# |              Open|             Close|
# +------------------+------------------+
# |        213.429998|        214.009998|
# |        214.599998|        214.379993|
# |        214.379993|        210.969995|
# |            211.75|            210.58|
# |        210.299994|211.98000499999998|
# |212.79999700000002|210.11000299999998|
# |209.18999499999998|        207.720001|
# |        207.870005|        210.650002|
# |210.11000299999998|            209.43|
# |210.92999500000002|            205.93|
# |        208.330002|        215.039995|
# |        214.910006|            211.73|
# |        212.079994|        208.069996|
# |206.78000600000001|            197.75|
# |202.51000200000001|        203.070002|
# |205.95000100000001|        205.940001|
# |        206.849995|        207.880005|
# |        204.930004|        199.289995|
# |        201.079996|        192.060003|
# |192.36999699999998|        194.729998|
# ...

# %% [markdown]
# Lay nhung dong co gia Close < 200 va Open < 200, chi hien thi 2 cot Open va Close

# %%
df.filter('Close < 200 and Open < 200').select(['Open','Close']).show()
# Out:
# +------------------+------------------+
# |              Open|             Close|
# +------------------+------------------+
# |192.36999699999998|        194.729998|
# |        195.909998|        195.859997|
# |        195.169994|        199.229994|
# |        196.730003|        192.050003|
# |192.63000300000002|        195.460001|
# |        195.690006|194.11999699999998|
# |        196.419996|196.19000400000002|
# |        195.889997|195.12000700000002|
# |        194.880001|        198.669994|
# |        199.999998|        197.059998|
# |         92.699997|         93.699997|
# |         94.730003|             94.25|
# |         94.129997|         93.860001|
# |         94.040001|         92.290001|
# |         92.199997|         91.279999|
# |         91.510002|         92.199997|
# |         92.309998| 92.08000200000001|
# |         92.269997|             92.18|
# |         92.290001|         91.860001|
# |         91.849998|         90.910004|
# ...

# %%
df.filter((df['Close'] < 200) & (df['Open'] < 200)).select(['Open','Close']).show()
# Out:
# +------------------+------------------+
# |              Open|             Close|
# +------------------+------------------+
# |192.36999699999998|        194.729998|
# |        195.909998|        195.859997|
# |        195.169994|        199.229994|
# |        196.730003|        192.050003|
# |192.63000300000002|        195.460001|
# |        195.690006|194.11999699999998|
# |        196.419996|196.19000400000002|
# |        195.889997|195.12000700000002|
# |        194.880001|        198.669994|
# |        199.999998|        197.059998|
# |         92.699997|         93.699997|
# |         94.730003|             94.25|
# |         94.129997|         93.860001|
# |         94.040001|         92.290001|
# |         92.199997|         91.279999|
# |         91.510002|         92.199997|
# |         92.309998| 92.08000200000001|
# |         92.269997|             92.18|
# |         92.290001|         91.860001|
# |         91.849998|         90.910004|
# ...

# %%
result = df.filter(df['Low'] == 197.16)

# %% [markdown]
# Lay nhung dong co Low = 197.16

# %%
result = df.filter('Low = 197.16').show()
# Out:
# +-------------------+------------------+----------+------+------+---------+---------+
# |               Date|              Open|      High|   Low| Close|   Volume|Adj Close|
# +-------------------+------------------+----------+------+------+---------+---------+
# |2010-01-22 00:00:00|206.78000600000001|207.499996|197.16|197.75|220441900|25.620401|
# +-------------------+------------------+----------+------+------+---------+---------+

# %%
row = result

# %%
row
# Out:
# DataFrame[Date: timestamp, Open: double, High: double, Low: double, Close: double, Volume: int, Adj Close: double]

# %%
x = row.asDict()['Volume']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-dee10283f582> in <module>
# ----> 1 x = row.asDict()['Volume']
#
# c:\Python39\lib\site-packages\pyspark\sql\dataframe.py in __getattr__(self, name)
#    1986         """
#    1987         if name not in self.columns:
# -> 1988             raise AttributeError(
#    1989                 "'%s' object has no attribute '%s'" % (self.__class__.__name__, name)
#    1990             )
#
# AttributeError: 'DataFrame' object has no attribute 'asDict'
